# %%
import numpy as np
import matplotlib.pyplot as plt
import sys,os
import math
from pathlib import Path
parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))
#sys.path.append(r"\Users\13347\Documents\Yale\Paraproducts\Quasilinearization-of-potential-and-Schrodinger-kernels-with-tensor-paraproducts-main")
from tensor_paraproducts import haar_paraproduct
import pickle
import time

# %%
# Load data
with open("XPdict.pkl", "rb") as f:
    XPdict = pickle.load(f)

# %% [markdown]
# # Figure 1

# %%
N = 256
jmax = int(math.log2(N)) - 1
eps = 2**(-jmax)

k=0
delt= 3e-3
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
tf1 = XPdict[strg][1][-1]
gt_f1 = XPdict[strg][1][0]
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d1_f1 = XPdict[strg][1][1]
delt= 3e-2
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d2_f1 = XPdict[strg][1][1]
delt= 3e-1
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d3_f1 = XPdict[strg][1][1]


k=1
delt= 3e-3
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
tf2 = XPdict[strg][1][-1]
gt_f2 = XPdict[strg][1][0]
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d1_f2 = XPdict[strg][1][1]
delt= 3e-2
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d2_f2 = XPdict[strg][1][1]
delt= 3e-1
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d3_f2 = XPdict[strg][1][1]


k=2
delt = 3e-3
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
tf3 = XPdict[strg][1][-1]
gt_f3 = XPdict[strg][1][0]
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d1_f3 = XPdict[strg][1][1]
delt= 3e-2
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d2_f3 = XPdict[strg][1][1]
delt= 3e-1
strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
app_d3_f3 = XPdict[strg][1][1]


fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(tf1,linewidth=3)
axes[0, 0].plot(tf2,linewidth=3)
axes[0, 0].plot(tf3,linewidth=3)
axes[0, 0].set_title("Test functions ",fontsize=16)
axes[0, 0].legend([r"$f_1$",r"$f_2$",r"$f_3$"])
axes[0, 0].set_xlabel("Grid points (a) ",fontsize=16)
axes[0, 0].set_ylabel("Magnitude",fontsize=16)

axes[0, 1].plot(gt_f1,linewidth=7)
axes[0, 1].plot(app_d1_f1,"--",markersize=3)
axes[0, 1].plot(app_d2_f1,"^",markersize=3)
axes[0, 1].plot(app_d3_f1,"+",markersize=3)
axes[0, 1].set_title(rf"$g_1$ $(M=256,\epsilon=8e-3)$",fontsize=16)
axes[0, 1].legend(["Ground truth",r"$\delta$ = 3e-3", r"$\delta$ = 3e-2", r"$\delta$ = 3e-1"])
axes[0, 1].set_xlabel("Grid points (b) ",fontsize=16)
axes[0, 1].set_ylabel("Magnitude",fontsize=16)

axes[1, 0].plot(gt_f2,linewidth=7)
axes[1, 0].plot(app_d1_f2,"--",markersize=3)
axes[1, 0].plot(app_d2_f2,"^",markersize=3)
axes[1, 0].plot(app_d3_f2,"+",markersize=3)
axes[1, 0].set_title(rf"$g_2$ $(M=256,\epsilon=8e-3)$",fontsize=16)
axes[1, 0].legend(["Ground truth",r"$\delta$ = 3e-3", r"$\delta$ = 3e-2", r"$\delta$ = 3e-1"])
axes[1, 0].set_xlabel("Grid points (c) ",fontsize=16)
axes[1, 0].set_ylabel("Magnitude",fontsize=16)

axes[1, 1].plot(gt_f3,linewidth=7)
axes[1, 1].plot(app_d1_f3,"--",markersize=3)
axes[1, 1].plot(app_d2_f3,"^",markersize=3)
axes[1, 1].plot(app_d3_f3,"+",markersize=3)
axes[1, 1].set_title(rf"$g_3$ $(M=256,\epsilon=8e-3)$",fontsize=16)
axes[1, 1].legend(["Ground truth",r"$\delta$ = 3e-3", r"$\delta$ = 3e-2", r"$\delta$ = 3e-1"])
axes[1, 1].set_xlabel("Grid points (d) ",fontsize=16)
axes[1, 1].set_ylabel("Magnitude",fontsize=16)

plt.subplots_adjust(hspace=0.5)


plt.savefig("/home/fash/Documents/Paraproducts/Quasilinearization-of-potential-and-Schrodinger-kernels-with-tensor-paraproducts-main/Figures_pot_schrod/mv_multfig.png")


plt.tight_layout()
plt.show()

# %% [markdown]
# # Tables

# %%
import pandas as pd
dimlist = [128,256,512]
metable = []
for N in dimlist:
    prec = [int(math.log2(N)) - 1,int(math.log2(N)),int(math.log2(N)) + 1]
    for j in prec:
        eps = 2**(-j)
        print("epsilon",eps)
        k=0
        delt= 3e-1
        strg = str(N) + "_" + str(eps) + "_" + str(delt) + "fcn_" + str(k)
        metable.append([XPdict[strg][0][0],XPdict[strg][0][1],XPdict[strg][0][2]])

df = pd.DataFrame(metable, columns=[r"$L^2$", r"$L^{\infty}$", "CR"])
latex_table = df.to_latex(index=False)
print(latex_table)
# Out:
# epsilon 0.015625
# epsilon 0.0078125
# epsilon 0.00390625
# epsilon 0.0078125
# epsilon 0.00390625
# epsilon 0.001953125
# epsilon 0.00390625
# epsilon 0.001953125
# epsilon 0.0009765625
# \begin{tabular}{rrr}
# \toprule
# $L^2$ & $L^{\infty}$ & CR \\
# \midrule
# 0.053149 & 0.048594 & 64.000000 \\
# 0.028634 & 0.027317 & 36.571429 \\
# 0.018522 & 0.014951 & 44.521739 \\
# 0.027768 & 0.027052 & 42.666667 \\
# 0.018491 & 0.014864 & 37.925926 \\
# 0.026745 & 0.030954 & 93.090909 \\
# 0.018486 & 0.014826 & 36.571429 \\
# 0.025308 & 0.027722 & 97.523810 \\
# 0.030518 & 0.032449 & 44.161725 \\
# \bottomrule
# \end{tabular}
